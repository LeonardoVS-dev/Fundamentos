# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoVS-dev/Fundamentos/blob/main/Fundamentos_Analise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Básico 1

# %%
# String
n = 3
texto = input("Digite um texto:\n").strip()

print("palavra" * n)
print((texto + "abc") * 2)
print(type(texto))

idade = input("\nDigite sua idade:\n").strip()
nome = input("Digite seu nome:\n").strip()
# Usando o f string
print(f"Olá, {nome}! Você tem {idade} anos")
# Ou também
print("Olá, {}! Você tem {} anos".format(nome, idade))

# %%
# Índices de string
#[início:fim:salto]

print(len(texto))
print(texto[0::2])
print(texto[0:3:1])
print(texto[0::3])

# %%
# Métodos de string
lorem_ipsum = "Lorem ipsum dolor sit amet"
input_user = input("Digite um texto:").strip()
lista_lorem = lorem_ipsum.split(" ")

print(", ".join(lista_lorem))
print(lorem_ipsum.title())
print(lorem_ipsum.startswith("L"))
print(input_user.count("a"))
print(lorem_ipsum.replace("Lorem", "Python"))
print(input_user.find(" "))
print("O primeiro 'a' está na posição" , input_user.find("a"))
# Out:
# Digite um texto:mdmlfnlknsda
# Lorem, ipsum, dolor, sit, amet
# Lorem Ipsum Dolor Sit Amet
# True
# 1
# Python ipsum dolor sit amet
# -1
# O primeiro 'a' está na posição 11

# %%
#Operadores e condicionais

continente = input("Digite um continente")
pais = input("Digite um país nesse continente")
print(continente + ' é o continente de ' + pais)

print(((100%3) * 2) + 20 )
print((257//5.2) ** 3)

num = int(input("Digite um número"))

if num >= 6:
  print("maior que seis")
else:
  for i in range(num):
    print(i)
    i += 1

if "a" in pais:
  print(pais.count("a"))
if "e" in pais:
  print(pais.count("e"))
else:
  print("sem a nem e")
# Out:
# Digite um continenteAmérica
# Digite um país nesse continenteEstados Unidos da America
# América é o continente da Estados Unidos da America
# 22
# 117649.0
# Digite um número0328493
# maior que seis
# 3

# %%
#Conversão

a = 10
b = str(a)
c = float(a)

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
